# %%
import pandas as pd
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv("Automobile_data.csv")
df
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %%
df["company"][df["wheel-base"] == 88.6]
# Out:
# 0    alfa-romero
# 1    alfa-romero
# Name: company, dtype: object

# %%
df["company"].isin(["alfa-romero"])
# Out:
# 0      True
# 1      True
# 2      True
# 3     False
# 4     False
#       ...
# 56    False
# 57    False
# 58    False
# 59    False
# 60    False
# Name: company, Length: 61, dtype: bool

# %%
df["company"].isin(["alfa-romero"]).sum()
# Out:
# 3

# %%
df[df["wheel-base"] == 88.6]
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0

# %%
df[["company" , "length"]][df["wheel-base"]==df["wheel-base"].max()]
# Out:
#           company  length
# 34  mercedes-benz   208.1

# %%
df.loc[:3]
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0

# %%
df.iloc[:3]
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0

# %%
df.isna()
# Out:
#     index  company  body-style  wheel-base  length  engine-type  \
# 0   False    False       False       False   False        False
# 1   False    False       False       False   False        False
# 2   False    False       False       False   False        False
# 3   False    False       False       False   False        False
# 4   False    False       False       False   False        False
# ..    ...      ...         ...         ...     ...          ...
# 56  False    False       False       False   False        False
# 57  False    False       False       False   False        False
# 58  False    False       False       False   False        False
# 59  False    False       False       False   False        False
# 60  False    False       False       False   False        False
#
#     num-of-cylinders  horsepower  average-mileage  price
# 0              False       False            False  False
# 1              False       False            False  False
# ...

# %%
df.isnull().sum()
# Out:
# index               0
# company             0
# body-style          0
# wheel-base          0
# length              0
# engine-type         0
# num-of-cylinders    0
# horsepower          0
# average-mileage     0
# price               3
# dtype: int64

# %%
df.fillna(0 , inplace=True)

# %%
df.isna().sum()
# Out:
# index               0
# company             0
# body-style          0
# wheel-base          0
# length              0
# engine-type         0
# num-of-cylinders    0
# horsepower          0
# average-mileage     0
# price               0
# dtype: int64

# %%
df.dropna(inplace=True) #drop row

# %%
for i , j in df.head().iterrows():
    print(i)
    print(j )
    print()
# Out:
# 0
# index                         0
# company             alfa-romero
# body-style          convertible
# wheel-base                 88.6
# length                    168.8
# engine-type                dohc
# num-of-cylinders           four
# horsepower                  111
# average-mileage              21
# price                   13495.0
# Name: 0, dtype: object
#
# 1
# index                         1
# company             alfa-romero
# body-style          convertible
# wheel-base                 88.6
# length                    168.8
# engine-type                dohc
# num-of-cylinders           four
# horsepower                  111
# average-mileage              21
# price                   16500.0
# Name: 1, dtype: object
#
# 2
# index                         2
# company             alfa-romero
# body-style            hatchback
# wheel-base                 94.5
# length                    171.2
# engine-type                ohcv
# num-of-cylinders            six
# ...

# %%
df.columns
# Out:
# Index(['index', 'company', 'body-style', 'wheel-base', 'length', 'engine-type',
#        'num-of-cylinders', 'horsepower', 'average-mileage', 'price'],
#       dtype='object')

# %%
list(df)
# Out:
# ['index',
#  'company',
#  'body-style',
#  'wheel-base',
#  'length',
#  'engine-type',
#  'num-of-cylinders',
#  'horsepower',
#  'average-mileage',
#  'price']

# %%
len(df)
# Out:
# 61

# %%
df.insert(2,"random" , [random.randint(1,70) for _ in range(0, len(df))] , allow_duplicates=False)
df
# Out:
#     index      company  random   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero      69  convertible        88.6   168.8        dohc
# 1       1  alfa-romero      19  convertible        88.6   168.8        dohc
# 2       2  alfa-romero      26    hatchback        94.5   171.2        ohcv
# 3       3         audi      39        sedan        99.8   176.6         ohc
# 4       4         audi       2        sedan        99.4   176.6         ohc
# ..    ...          ...     ...          ...         ...     ...         ...
# 56     81   volkswagen      44        sedan        97.3   171.7         ohc
# 57     82   volkswagen      36        sedan        97.3   171.7         ohc
# 58     86   volkswagen      60        sedan        97.3   171.7         ohc
# 59     87        volvo       1        sedan       104.3   188.8         ohc
# 60     88        volvo      18        wagon       104.3   188.8         ohc
#
# ...

# %%
df.at[2,"random"]= np.nan
df.iloc[[0,1],[2]] = np.nan

# %%
df
# Out:
#     index      company  random   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero     NaN  convertible        88.6   168.8        dohc
# 1       1  alfa-romero     NaN  convertible        88.6   168.8        dohc
# 2       2  alfa-romero     NaN    hatchback        94.5   171.2        ohcv
# 3       3         audi    41.0        sedan        99.8   176.6         ohc
# 4       4         audi     4.0        sedan        99.4   176.6         ohc
# ..    ...          ...     ...          ...         ...     ...         ...
# 56     81   volkswagen    46.0        sedan        97.3   171.7         ohc
# 57     82   volkswagen    38.0        sedan        97.3   171.7         ohc
# 58     86   volkswagen    62.0        sedan        97.3   171.7         ohc
# 59     87        volvo     3.0        sedan       104.3   188.8         ohc
# 60     88        volvo    20.0        wagon       104.3   188.8         ohc
#
# ...

# %%
df.random = df["random"].add(1 , fill_value=5)
df
# Out:
#     index      company  random   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero     6.0  convertible        88.6   168.8        dohc
# 1       1  alfa-romero     6.0  convertible        88.6   168.8        dohc
# 2       2  alfa-romero     6.0    hatchback        94.5   171.2        ohcv
# 3       3         audi    42.0        sedan        99.8   176.6         ohc
# 4       4         audi     5.0        sedan        99.4   176.6         ohc
# ..    ...          ...     ...          ...         ...     ...         ...
# 56     81   volkswagen    47.0        sedan        97.3   171.7         ohc
# 57     82   volkswagen    39.0        sedan        97.3   171.7         ohc
# 58     86   volkswagen    63.0        sedan        97.3   171.7         ohc
# 59     87        volvo     4.0        sedan       104.3   188.8         ohc
# 60     88        volvo    21.0        wagon       104.3   188.8         ohc
#
# ...

# %%
df.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# e:\Data Science\pr1.ipynb Cell 21 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/e%3A/Data%20Science/pr1.ipynb#X43sZmlsZQ%3D%3D?line=0'>1</a> df.unique()
#
# File c:\Users\kulde\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
df.random.unique()
# Out:
# array([ 6., 42.,  5., 60., 61., 36., 44., 48., 15., 33., 56., 73., 21.,
#        71., 39., 69., 22., 30., 58., 11., 26., 57., 63., 47., 70., 59.,
#        29., 18., 51.,  9., 49., 46., 25., 27., 19., 14.,  4., 37., 40.,
#        23., 45., 13.])

# %%
df.nunique()
# Out:
# index               61
# company             16
# random              42
# body-style           5
# wheel-base          27
# length              36
# engine-type          7
# num-of-cylinders     7
# horsepower          30
# average-mileage     21
# price               58
# dtype: int64

# %%
df.random.nunique()
# Out:
# 42

# %%
df.notnull()
# Out:
#     index  company  random  body-style  wheel-base  length  engine-type  \
# 0    True     True    True        True        True    True         True
# 1    True     True    True        True        True    True         True
# 2    True     True    True        True        True    True         True
# 3    True     True    True        True        True    True         True
# 4    True     True    True        True        True    True         True
# ..    ...      ...     ...         ...         ...     ...          ...
# 56   True     True    True        True        True    True         True
# 57   True     True    True        True        True    True         True
# 58   True     True    True        True        True    True         True
# 59   True     True    True        True        True    True         True
# 60   True     True    True        True        True    True         True
#
#     num-of-cylinders  horsepower  average-mileage  price
# ...

# %%
df.iloc[2,[2]] = np.nan
df
# Out:
#     index      company  random   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero     6.0  convertible        88.6   168.8        dohc
# 1       1  alfa-romero     6.0  convertible        88.6   168.8        dohc
# 2       2  alfa-romero     NaN    hatchback        94.5   171.2        ohcv
# 3       3         audi    42.0        sedan        99.8   176.6         ohc
# 4       4         audi     5.0        sedan        99.4   176.6         ohc
# ..    ...          ...     ...          ...         ...     ...         ...
# 56     81   volkswagen    47.0        sedan        97.3   171.7         ohc
# 57     82   volkswagen    39.0        sedan        97.3   171.7         ohc
# 58     86   volkswagen    63.0        sedan        97.3   171.7         ohc
# 59     87        volvo     4.0        sedan       104.3   188.8         ohc
# 60     88        volvo    21.0        wagon       104.3   188.8         ohc
#
# ...

# %%
# df = df.replace("value" , "new value")
# df = df.replace(["value"] , "new value")
# df = df.replace({"col1":"value"} , "new value")
# df = df.replace({"value": "new value"} )
# df = df.replace({"col1": "[A-Za-z]"},"" ,regex=True)
# df = df.replace("[A-Za-z]" ," " , regex=True)
# df = df.replace(["value1" , "value2"] , ["new value1" , "new value2"])

# %%
df.dropna(inplace=True)
# df.dropna(how="all") #if all are null in row
# df.dropna(thresh=1) # will keep if more than 1 value are not null  in row
df.head()
# Out:
#    index company  random body-style  wheel-base  length engine-type  \
# 3      3    audi    42.0      sedan        99.8   176.6         ohc
# 4      4    audi     5.0      sedan        99.4   176.6         ohc
# 5      5    audi    60.0      sedan        99.8   177.3         ohc
# 6      6    audi    61.0      wagon       105.8   192.7         ohc
# 7      9     bmw    36.0      sedan       101.2   176.8         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 3             four         102               24  13950.0
# 4             five         115               18  17450.0
# 5             five         110               19  15250.0
# 6             five         110               19  18920.0
# 7             four         101               23  16430.0

# %%
df.drop([3] , inplace=True)
df
# Out:
#     index        company  random   body-style  wheel-base  length engine-type  \
# 4       4           audi     5.0        sedan        99.4   176.6         ohc
# 5       5           audi    60.0        sedan        99.8   177.3         ohc
# 6       6           audi    61.0        wagon       105.8   192.7         ohc
# 7       9            bmw    36.0        sedan       101.2   176.8         ohc
# 8      10            bmw    44.0        sedan       101.2   176.8         ohc
# 9      11            bmw     5.0        sedan       101.2   176.8         ohc
# 10     13            bmw    48.0        sedan       103.5   189.0         ohc
# 11     14            bmw    15.0        sedan       103.5   193.8         ohc
# 12     15            bmw    33.0        sedan       110.0   197.0         ohc
# 13     16      chevrolet    56.0    hatchback        88.4   141.1           l
# 14     17      chevrolet    73.0    hatchback        94.5   155.9         ohc
# ...

# %%
df = df[:20]
df
# Out:
#     index    company  random body-style  wheel-base  length engine-type  \
# 4       4       audi     5.0      sedan        99.4   176.6         ohc
# 5       5       audi    60.0      sedan        99.8   177.3         ohc
# 6       6       audi    61.0      wagon       105.8   192.7         ohc
# 7       9        bmw    36.0      sedan       101.2   176.8         ohc
# 8      10        bmw    44.0      sedan       101.2   176.8         ohc
# 9      11        bmw     5.0      sedan       101.2   176.8         ohc
# 10     13        bmw    48.0      sedan       103.5   189.0         ohc
# 11     14        bmw    15.0      sedan       103.5   193.8         ohc
# 12     15        bmw    33.0      sedan       110.0   197.0         ohc
# 13     16  chevrolet    56.0  hatchback        88.4   141.1           l
# 14     17  chevrolet    73.0  hatchback        94.5   155.9         ohc
# 15     18  chevrolet    21.0      sedan        94.5   158.8         ohc
# ...

# %%
df.drop(["random"] , inplace=True , axis=1)
df
# Out:
# C:\Users\kulde\AppData\Local\Temp\ipykernel_20744\652264663.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(["random"] , inplace=True , axis=1)
#     index    company body-style  wheel-base  length engine-type  \
# 4       4       audi      sedan        99.4   176.6         ohc
# 5       5       audi      sedan        99.8   177.3         ohc
# 6       6       audi      wagon       105.8   192.7         ohc
# 7       9        bmw      sedan       101.2   176.8         ohc
# 8      10        bmw      sedan       101.2   176.8         ohc
# 9      11        bmw      sedan       101.2   176.8         ohc
# 10     13        bmw      sedan       103.5   189.0         ohc
# 11     14        bmw      sedan       103.5   193.8         ohc
# ...

# %%
engine_type = df.pop("engine-type")
df
# Out:
#     index    company body-style  wheel-base  length num-of-cylinders  \
# 4       4       audi      sedan        99.4   176.6             five
# 5       5       audi      sedan        99.8   177.3             five
# 6       6       audi      wagon       105.8   192.7             five
# 7       9        bmw      sedan       101.2   176.8             four
# 8      10        bmw      sedan       101.2   176.8             four
# 9      11        bmw      sedan       101.2   176.8              six
# 10     13        bmw      sedan       103.5   189.0              six
# 11     14        bmw      sedan       103.5   193.8              six
# 12     15        bmw      sedan       110.0   197.0              six
# 13     16  chevrolet  hatchback        88.4   141.1            three
# 14     17  chevrolet  hatchback        94.5   155.9             four
# 15     18  chevrolet      sedan        94.5   158.8             four
# 16     19      dodge  hatchback        93.7   157.3             four
# ...

# %%
df.duplicated()
# Out:
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#     index    company body-style  wheel-base  length num-of-cylinders  \
# 4       4       audi      sedan        99.4   176.6             five
# 5       5       audi      sedan        99.8   177.3             five
# 6       6       audi      wagon       105.8   192.7             five
# 7       9        bmw      sedan       101.2   176.8             four
# 8      10        bmw      sedan       101.2   176.8             four
# 9      11        bmw      sedan       101.2   176.8              six
# 10     13        bmw      sedan       103.5   189.0              six
# 11     14        bmw      sedan       103.5   193.8              six
# 12     15        bmw      sedan       110.0   197.0              six
# 13     16  chevrolet  hatchback        88.4   141.1            three
# 14     17  chevrolet  hatchback        94.5   155.9             four
# 15     18  chevrolet      sedan        94.5   158.8             four
# 16     19      dodge  hatchback        93.7   157.3             four
# ...

# %%
df.duplicated(subset=["company"]).sum()
# Out:
# 45

# %%
df.duplicated(subset=["company" , "body-style" , "length" , "wheel-base"])
# Out:
# 0     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 24    False
# 26    False
# 27    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 38    False
# 40    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 51    False
# 54    False
# 55    False
# 59    False
# 60    False
# dtype: bool

# %%
df = df.loc[~df.duplicated(subset=["company" , "body-style" , "length" , "wheel-base"])].copy() #not duplicated
df.head(5)
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
# 5      5         audi        sedan        99.8   177.3         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0
# 4             five         115               18  17450.0
# 5             five         110               19  15250.0

# %%
df.reset_index(drop=True).head(5)
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 2      3         audi        sedan        99.8   176.6         ohc
# 3      4         audi        sedan        99.4   176.6         ohc
# 4      5         audi        sedan        99.8   177.3         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1              six         154               19  16500.0
# 2             four         102               24  13950.0
# 3             five         115               18  17450.0
# 4             five         110               19  15250.0

# %%
df.query('company=="bmw"')
# Out:
#     index company body-style  wheel-base  length engine-type num-of-cylinders  \
# 7       9     bmw      sedan       101.2   176.8         ohc             four
# 10     13     bmw      sedan       103.5   189.0         ohc              six
# 11     14     bmw      sedan       103.5   193.8         ohc              six
# 12     15     bmw      sedan       110.0   197.0         ohc              six
#
#     horsepower  average-mileage    price
# 7          101               23  16430.0
# 10         182               16  30760.0
# 11         182               16  41315.0
# 12         182               15  36880.0

# %%
con= df["company"] == "bmw"
df.where(con).dropna()
# Out:
#     index company body-style  wheel-base  length engine-type num-of-cylinders  \
# 7     9.0     bmw      sedan       101.2   176.8         ohc             four
# 10   13.0     bmw      sedan       103.5   189.0         ohc              six
# 11   14.0     bmw      sedan       103.5   193.8         ohc              six
# 12   15.0     bmw      sedan       110.0   197.0         ohc              six
#
#     horsepower  average-mileage    price
# 7        101.0             23.0  16430.0
# 10       182.0             16.0  30760.0
# 11       182.0             16.0  41315.0
# 12       182.0             15.0  36880.0

# %%
df["num-of-cylinders"].value_counts()
# Out:
# four      22
# six        9
# five       5
# eight      3
# three      1
# twelve     1
# two        1
# Name: num-of-cylinders, dtype: int64

# %%
df["num-of-cylinders"].value_counts() \
    .plot()
# Out:
# <AxesSubplot:>

# %%
df["num-of-cylinders"].value_counts() \
    .plot(kind="area") #"bar"
# Out:
# <AxesSubplot:>

# %%
df.plot(kind="scatter" ,x="horsepower" , y="average-mileage" ) #plot create an matplotlib object
plt.show()

# %%
sns.scatterplot(data=df , x="horsepower" , y="average-mileage" , hue="num-of-cylinders")
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='average-mileage'>

# %%
sns.pairplot(df , vars=["wheel-base" , "length" , "horsepower"] , hue="company")
plt.show()

# %%
ax = df["num-of-cylinders"].value_counts() \
    .plot(kind="bar" , title="title of plot") #"bar"
ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")
# Out:
# Text(0, 0.5, 'Y-axis')

# %%
df.corr()
# Out:
#                     index  wheel-base    length  horsepower  average-mileage  \
# index            1.000000    0.082849  0.107285    0.062573         0.082112
# wheel-base       0.082849    1.000000  0.879152    0.384415        -0.519975
# length           0.107285    0.879152  1.000000    0.613988        -0.777005
# horsepower       0.062573    0.384415  0.613988    1.000000        -0.796834
# average-mileage  0.082112   -0.519975 -0.777005   -0.796834         1.000000
# price           -0.080554    0.611238  0.745949    0.671172        -0.706494
#
#                     price
# index           -0.080554
# wheel-base       0.611238
# length           0.745949
# horsepower       0.671172
# average-mileage -0.706494
# price            1.000000

# %%
sns.heatmap(df.corr() , annot=True)
# Out:
# <AxesSubplot:>

# %%
df.head(3)
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0

# %%
df.loc[df.price ==  df["price"].max()]
# Out:
#     index        company body-style  wheel-base  length engine-type  \
# 35     47  mercedes-benz    hardtop       112.0   199.2        ohcv
#
#    num-of-cylinders  horsepower  average-mileage    price
# 35            eight         184               14  45400.0

# %%
a = df.groupby("company")[["horsepower" , "average-mileage"]]
for i in a:
    print(i)
# Out:
# ('alfa-romero',    horsepower  average-mileage
# 0         111               21
# 2         154               19)
# ('audi',    horsepower  average-mileage
# 3         102               24
# 4         115               18
# 5         110               19
# 6         110               19)
# ('bmw',     horsepower  average-mileage
# 7          101               23
# 10         182               16
# 11         182               16
# 12         182               15)
# ('chevrolet',     horsepower  average-mileage
# 13          48               47
# 14          70               38
# 15          70               38)
# ('dodge',     horsepower  average-mileage
# 16          68               31)
# ('honda',     horsepower  average-mileage
# 18          76               30
# 19         101               24
# 20         100               25)
# ('isuzu',     horsepower  average-mileage
# 21          78               24
# 22          70               38)
# ...

# %%
a = df.groupby("company")[["horsepower" , "average-mileage"]].agg(["mean" , "count"] )
a
# Out:
#                horsepower       average-mileage
#                      mean count            mean count
# company
# alfa-romero    132.500000     2       20.000000     2
# audi           109.250000     4       20.000000     4
# bmw            161.750000     4       17.500000     4
# chevrolet       62.666667     3       41.000000     3
# dodge           68.000000     1       31.000000     1
# honda           92.333333     3       26.333333     3
# isuzu           74.000000     2       31.000000     2
# jaguar         219.000000     2       14.000000     2
# mazda           80.333333     3       26.000000     3
# mercedes-benz  153.500000     4       18.000000     4
# mitsubishi      78.000000     2       31.000000     2
# nissan          92.000000     3       31.666667     3
# porsche        234.000000     3       17.000000     3
# toyota          93.333333     3       28.333333     3
# volkswagen      52.000000     1       37.000000     1
# ...

# %%
a.sort_values(by="company")
# Out:
#                horsepower       average-mileage
#                      mean count            mean count
# company
# alfa-romero    132.500000     2       20.000000     2
# audi           109.250000     4       20.000000     4
# bmw            161.750000     4       17.500000     4
# chevrolet       62.666667     3       41.000000     3
# dodge           68.000000     1       31.000000     1
# honda           92.333333     3       26.333333     3
# isuzu           74.000000     2       31.000000     2
# jaguar         219.000000     2       14.000000     2
# mazda           80.333333     3       26.000000     3
# mercedes-benz  153.500000     4       18.000000     4
# mitsubishi      78.000000     2       31.000000     2
# nissan          92.000000     3       31.666667     3
# porsche        234.000000     3       17.000000     3
# toyota          93.333333     3       28.333333     3
# volkswagen      52.000000     1       37.000000     1
# ...

# %%
a.columns = a.columns.map('_'.join)

# %%
a.sort_values("horsepower_mean" , ascending=False).head(10).plot(kind="line")
# Out:
# <AxesSubplot:xlabel='company'>

# %%
ax = sns.countplot(data=df , y="company")
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %%
li = ['s', 'a', 't' , 't', np.nan]
# df2 = pd.read_csv("li",header=None ,names=["sss","ddd" ,"fff" ,"ggg" ,"rrr"]\
    # , nrows=3 , na_values=["not available" , "n.a."])
# df2 = pd.read_csv("li" , na_values={"col1":["not available" , "n.a."] , "col2": ["not available" ]})
df2 = pd.DataFrame(li )
df2
# Out:
#      0
# 0    s
# 1    a
# 2    t
# 3    t
# 4  NaN

# %%
df2.columns = ["sss"]

# %%
pd.get_dummies(df2)
# Out:
#    sss_a  sss_s  sss_t
# 0      0      1      0
# 1      1      0      0
# 2      0      0      1
# 3      0      0      1
# 4      0      0      0

# %%
df2.rename(columns={"sss": "aaa"})
# Out:
#      0
# 0    s
# 1    a
# 2    t
# 3    t
# 4  NaN

# %%
# a = pd.concat([df , df2])  #row wise
# a = pd.concat([df , df2] , axis=1)  #column wise
# a = pd.concat([df , df2] , axis=1 , ignore_index=True) 
# a = pd.concat([df , df2] , keys=["a" , "b"]) 
# a = pd.concat([df , df2] , axis=1 ) 
# a = pd.merge(df , df2 , on="city" ) #common column name #intersection
# a = pd.merge(df , df2 , on="city", how="outer") #common column name #union
# a = pd.merge(df , df2 , on="city", how="outer" , indicator=True) #common column name #union
# a = pd.merge(df , df2 , on="city", how="left") #common column name #left outer join
# a = pd.merge(df , df2 , on="city", how="right") #common column name #right outer join

# %%
dic = {
    "date": ["12/12/22","72/42/22","11/11/22","1/2/22"],
    "city" : [ "jaipur" , "ajmer" , "kota" , np.NaN],
    "temp" : [ 12,34,45,67],
    "humidity" : [ 1,554,77,45],
}
df4 = pd.DataFrame((dic))
df4
# Out:
#        date    city  temp  humidity
# 0  12/12/22  jaipur    12         1
# 1  72/42/22   ajmer    34       554
# 2  11/11/22    kota    45        77
# 3    1/2/22     NaN    67        45

# %%
df4.pivot(index="city" , columns="date")
# Out:
#          temp                            humidity
# date   1/2/22 11/11/22 12/12/22 72/42/22   1/2/22 11/11/22 12/12/22 72/42/22
# city
# NaN      67.0      NaN      NaN      NaN     45.0      NaN      NaN      NaN
# ajmer     NaN      NaN      NaN     34.0      NaN      NaN      NaN    554.0
# jaipur    NaN      NaN     12.0      NaN      NaN      NaN      1.0      NaN
# kota      NaN     45.0      NaN      NaN      NaN     77.0      NaN      NaN

# %%
df4.pivot(index="date" , columns=["city"])
# Out:
#           temp                    humidity
# city       NaN ajmer jaipur  kota      NaN  ajmer jaipur  kota
# date
# 1/2/22    67.0   NaN    NaN   NaN     45.0    NaN    NaN   NaN
# 11/11/22   NaN   NaN    NaN  45.0      NaN    NaN    NaN  77.0
# 12/12/22   NaN   NaN   12.0   NaN      NaN    NaN    1.0   NaN
# 72/42/22   NaN  34.0    NaN   NaN      NaN  554.0    NaN   NaN

# %%
dic = {
    "date": ["12/12/22","12/12/22","11/11/22","1/2/22"],
    "city" : [ "jaipur" , "ajmer" , "kota" , np.NaN],
    "temp" : [ 12,34,45,67],
    "humidity" : [ 1,554,77,45],
}
df5 = pd.DataFrame((dic))
df

# %%
a = "Name	Nationality	Sex	Age	Handedness\
 Kathy	USA	Female	23	Right\
Linda	USA	Female	18	Right\
Peter	USA	Male	19	Right\
John	USA	Male	22	Left\
Fatima	Bangadesh	Female	31	Left\
Kadir	Bangadesh	Male	25	Left\
Dhaval	India	Male	35	Left\
Sudhir	India	Male	31	Left\
Parvir	India	Male	37	Right\
Yan	China	Female	52	Right\
Juan	China	Female	58	Left\
Liang	China	Male	43	Left  "

# %%
b= b.replace("  " , ",")
print(b)
# Out:
# Name	Nationality	Sex	Age	Handedness Kathy	USA	Female	23	RightLinda	USA	Female	18	RightPeter	USA	Male	19	RightJohn	USA	Male	22	LeftFatima	Bangadesh	Female	31	LeftKadir	Bangadesh	Male	25	LeftDhaval	India	Male	35	LeftSudhir	India	Male	31	LeftParvir	India	Male	37	RightYan	China	Female	52	RightJuan	China	Female	58	LeftLiang	China	Male	43	Left,
